# %%
import pandas as pd
df = pd.read_csv("titanic.csv")
df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)
df.head()
# Out:
#    Pclass     Sex   Age     Fare  Survived
# 0       3    male  22.0   7.2500         0
# 1       1  female  38.0  71.2833         1
# 2       3  female  26.0   7.9250         1
# 3       1  female  35.0  53.1000         1
# 4       3    male  35.0   8.0500         0

# %%
inputs = df.drop('Survived',axis='columns')
target = df.Survived

# %%
#inputs.Sex = inputs.Sex.map({'male': 1, 'female': 2})
dummies = pd.get_dummies(inputs.Sex,dtype='int')
dummies.head(3)
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0

# %%
inputs = pd.concat([inputs,dummies],axis='columns')
inputs.head(3)
# Out:
#    Pclass     Sex   Age     Fare  female  male
# 0       3    male  22.0   7.2500       0     1
# 1       1  female  38.0  71.2833       1     0
# 2       3  female  26.0   7.9250       1     0

# %%
inputs.drop(['Sex','male'],axis='columns',inplace=True)
inputs.head(3)
# Out:
#    Pclass   Age     Fare  female
# 0       3  22.0   7.2500       0
# 1       1  38.0  71.2833       1
# 2       3  26.0   7.9250       1

# %%
inputs.columns[inputs.isna().any()]
# Out:
# Index(['Age'], dtype='object')

# %%
inputs.Age[:10]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
inputs.Age = inputs.Age.fillna(inputs.Age.mean())
inputs.head()
# Out:
#    Pclass     Sex   Age     Fare  female  male
# 0       3    male  22.0   7.2500       0     1
# 1       1  female  38.0  71.2833       1     0
# 2       3  female  26.0   7.9250       1     0
# 3       1  female  35.0  53.1000       1     0
# 4       3    male  35.0   8.0500       0     1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.3)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test,y_test)
# Out:
# 0.753731343283582

# %%
X_test[0:10]
# Out:
#      Pclass        Age     Fare  female
# 275       1  63.000000  77.9583       1
# 178       2  30.000000  13.0000       0
# 291       1  19.000000  91.0792       1
# 128       3  29.699118  22.3583       1
# 36        3  29.699118   7.2292       0
# 686       3  14.000000  39.6875       0
# 440       2  45.000000  26.2500       1
# 595       3  36.000000  24.1500       0
# 33        2  66.000000  10.5000       0
# 511       3  29.699118   8.0500       0

# %%
y_test[0:10]
# Out:
# 275    1
# 178    0
# 291    1
# 128    1
# 36     1
# 686    0
# 440    1
# 595    0
# 33     0
# 511    0
# Name: Survived, dtype: int64

# %%
model.predict(X_test[0:10])
# Out:
# array([1, 0, 1, 1, 0, 0, 1, 0, 0, 0], dtype=int64)

# %%
model.predict_proba(X_test[:10])
# Out:
# array([[0.01983178, 0.98016822],
#        [0.93808479, 0.06191521],
#        [0.0118484 , 0.9881516 ],
#        [0.47637261, 0.52362739],
#        [0.97003073, 0.02996927],
#        [0.95769308, 0.04230692],
#        [0.28335393, 0.71664607],
#        [0.97035642, 0.02964358],
#        [0.91477924, 0.08522076],
#        [0.97017903, 0.02982097]])

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(GaussianNB(),X_train, y_train, cv=5)
# Out:
# array([0.76      , 0.792     , 0.752     , 0.78225806, 0.78225806])
